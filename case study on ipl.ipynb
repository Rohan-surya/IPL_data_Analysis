# %% [markdown]
# Case study on descriptive statistics
# We will work on IPL Data Analysis and Visualization using Python where we will explore interesting insights from the data of IPL matches like most run by a player, most wicket taken by a player, and much more from IPL season 2008-2020.
#
# IPL dataset:Our IPL dataset contains ball by ball records from the first match played in the 2008 season till the complete 2020 season.

# %%
import pandas as pd
data=pd.read_csv(r"E:\Backup\Datasets\matches1.csv")
data
# Out:
#         id  season           city       date                        team1  \
# 0        1    2017      Hyderabad   4/5/2017          Sunrisers Hyderabad
# 1        2    2017           Pune   4/6/2017               Mumbai Indians
# 2        3    2017         Rajkot   4/7/2017                Gujarat Lions
# 3        4    2017         Indore   4/8/2017       Rising Pune Supergiant
# 4        5    2017      Bangalore   4/8/2017  Royal Challengers Bangalore
# ..     ...     ...            ...        ...                          ...
# 751  11347    2019         Mumbai   5/5/2019        Kolkata Knight Riders
# 752  11412    2019        Chennai   7/5/2019          Chennai Super Kings
# 753  11413    2019  Visakhapatnam   8/5/2019          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10/5/2019               Delhi Capitals
# 755  11415    2019      Hyderabad  12/5/2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
data.isnull()
# Out:
#         id  season   city   date  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 751  False   False  False  False  False  False        False          False
# 752  False   False  False  False  False  False        False          False
# 753  False   False  False  False  False  False        False          False
# 754  False   False  False  False  False  False        False          False
# 755  False   False  False  False  False  False        False          False
#
# ...

# %%
data.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
data.shape
# Out:
# (756, 18)

# %%
data.head()
# Out:
#    id  season       city      date                        team1  \
# 0   1    2017  Hyderabad  4/5/2017          Sunrisers Hyderabad
# 1   2    2017       Pune  4/6/2017               Mumbai Indians
# 2   3    2017     Rajkot  4/7/2017                Gujarat Lions
# 3   4    2017     Indore  4/8/2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  4/8/2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
data.tail()
# Out:
#         id  season           city       date                  team1  \
# 751  11347    2019         Mumbai   5/5/2019  Kolkata Knight Riders
# 752  11412    2019        Chennai   7/5/2019    Chennai Super Kings
# 753  11413    2019  Visakhapatnam   8/5/2019    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10/5/2019         Delhi Capitals
# 755  11415    2019      Hyderabad  12/5/2019         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 751           0       Mumbai Indians            0               9
# ...

# %%
data.head(10)
# Out:
#    id  season       city       date                        team1  \
# 0   1    2017  Hyderabad   4/5/2017          Sunrisers Hyderabad
# 1   2    2017       Pune   4/6/2017               Mumbai Indians
# 2   3    2017     Rajkot   4/7/2017                Gujarat Lions
# 3   4    2017     Indore   4/8/2017       Rising Pune Supergiant
# 4   5    2017  Bangalore   4/8/2017  Royal Challengers Bangalore
# 5   6    2017  Hyderabad   4/9/2017                Gujarat Lions
# 6   7    2017     Mumbai   4/9/2017        Kolkata Knight Riders
# 7   8    2017     Indore  4/10/2017  Royal Challengers Bangalore
# 8   9    2017       Pune  4/11/2017             Delhi Daredevils
# 9  10    2017     Mumbai  4/12/2017          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
data.tail(10)
# Out:
#         id  season           city       date                  team1  \
# 746  11342    2019         Mumbai   2/5/2019         Mumbai Indians
# 747  11343    2019         Mohali   3/5/2019        Kings XI Punjab
# 748  11344    2019          Delhi   4/5/2019       Rajasthan Royals
# 749  11345    2019      Bengaluru   4/5/2019    Sunrisers Hyderabad
# 750  11346    2019         Mohali   5/5/2019    Chennai Super Kings
# 751  11347    2019         Mumbai   5/5/2019  Kolkata Knight Riders
# 752  11412    2019        Chennai   7/5/2019    Chennai Super Kings
# 753  11413    2019  Visakhapatnam   8/5/2019    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10/5/2019         Delhi Capitals
# 755  11415    2019      Hyderabad  12/5/2019         Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 746          Sunrisers Hyderabad               Mumbai Indians           bat
# ...

# %%
data.sample()
# Out:
#       id  season    city       date                team1             team2  \
# 415  416    2013  Jaipur  4/27/2013  Sunrisers Hyderabad  Rajasthan Royals
#
#              toss_winner toss_decision  result  dl_applied            winner  \
# 415  Sunrisers Hyderabad           bat  normal           0  Rajasthan Royals
#
#      win_by_runs  win_by_wickets player_of_match                   venue  \
# 415            0               8     JP Faulkner  Sawai Mansingh Stadium
#
#          umpire1    umpire2 umpire3
# 415  VA Kulkarni  K Srinath     NaN

# %%
data.sample(10)
# Out:
#        id  season       city       date                        team1  \
# 674  7932    2018  Hyderabad   7/5/2018          Sunrisers Hyderabad
# 516   517    2014  Bangalore   6/1/2014              Kings XI Punjab
# 253   254    2011     Mumbai  4/20/2011                Pune Warriors
# 302   303    2011    Kolkata  5/22/2011        Kolkata Knight Riders
# 587   588    2016  Hyderabad  4/18/2016               Mumbai Indians
# 491   492    2014  Bangalore  5/11/2014  Royal Challengers Bangalore
# 229   230    2010    Kolkata  4/19/2010               Mumbai Indians
# 590   591    2016     Rajkot  4/21/2016                Gujarat Lions
# 554   555    2015    Kolkata   5/4/2015        Kolkata Knight Riders
# 262   263    2011      Delhi  4/26/2011             Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 674  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
data['city']
# Out:
# 0          Hyderabad
# 1               Pune
# 2             Rajkot
# 3             Indore
# 4          Bangalore
#            ...
# 751           Mumbai
# 752          Chennai
# 753    Visakhapatnam
# 754    Visakhapatnam
# 755        Hyderabad
# Name: city, Length: 756, dtype: object

# %%
data['city'].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
data['city'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
city_count=data['city'].value_counts().reset_index()
#print(city_count)
city_count.columns=['City','City Count']
print(city_count)
sns.barplot(x='City',y='City Count',data=city_count)
plt.title("Matches play by city")
plt.show()
# Out:
#               City  City Count
# 0           Mumbai         101
# 1          Kolkata          77
# 2            Delhi          74
# 3        Bangalore          66
# 4        Hyderabad          64
# 5          Chennai          57
# 6           Jaipur          47
# 7       Chandigarh          46
# 8             Pune          38
# 9           Durban          15
# 10       Bengaluru          14
# 11   Visakhapatnam          13
# 12       Centurion          12
# 13       Ahmedabad          12
# 14          Rajkot          10
# 15          Mohali          10
# 16          Indore           9
# 17      Dharamsala           9
# 18    Johannesburg           8
# 19         Cuttack           7
# 20          Ranchi           7
# 21  Port Elizabeth           7
# 22       Cape Town           7
# 23       Abu Dhabi           7
# 24         Sharjah           6
# 25          Raipur           6
# 26           Kochi           5
# 27          Kanpur           4
# 28          Nagpur           3
# ...

# %%
data.sample()
# Out:
#       id  season           city       date            team1  \
# 628  629    2016  Visakhapatnam  5/21/2016  Kings XI Punjab
#
#                        team2      toss_winner toss_decision  result  \
# 628  Rising Pune Supergiants  Kings XI Punjab           bat  normal
#
#      dl_applied                   winner  win_by_runs  win_by_wickets  \
# 628           0  Rising Pune Supergiants            0               4
#
#     player_of_match                                              venue  \
# 628        MS Dhoni  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
#
#              umpire1      umpire2 umpire3
# 628  HDPK Dharmasena  Nitin Menon     NaN

# %%
data['winner'].value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
winner_count=data['winner'].value_counts().reset_index()
print(winner_count)
winner_count.columns=['Team','Winner Count']
sns.barplot(x='Winner Count',y='Team',data=winner_count)
plt.title("Matches win by team")
plt.show()
# Out:
#                           index  winner
# 0                Mumbai Indians     109
# 1           Chennai Super Kings     100
# 2         Kolkata Knight Riders      92
# 3   Royal Challengers Bangalore      84
# 4               Kings XI Punjab      82
# 5              Rajasthan Royals      75
# 6              Delhi Daredevils      67
# 7           Sunrisers Hyderabad      58
# 8               Deccan Chargers      29
# 9                 Gujarat Lions      13
# 10                Pune Warriors      12
# 11       Rising Pune Supergiant      10
# 12               Delhi Capitals      10
# 13         Kochi Tuskers Kerala       6
# 14      Rising Pune Supergiants       5

# %%
data['win_by_runs'].max()
# Out:
# 146

# %%
plt.hist(data['win_by_runs'])
# Out:
# (array([536.,  96.,  54.,  25.,  14.,  16.,   7.,   2.,   2.,   4.]),
#  array([  0. ,  14.6,  29.2,  43.8,  58.4,  73. ,  87.6, 102.2, 116.8,
#         131.4, 146. ]),
#  <BarContainer object of 10 artists>)

# %%
data['season']
# Out:
# 0      2017
# 1      2017
# 2      2017
# 3      2017
# 4      2017
#        ...
# 751    2019
# 752    2019
# 753    2019
# 754    2019
# 755    2019
# Name: season, Length: 756, dtype: int64

# %%
data['season'].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2018    60
# 2019    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 751    False
# 752    False
# 753    False
# 754    False
# 755    False
# Length: 756, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %%
df2=data.drop_duplicates('season')
df2
# Out:
#         id  season       city       date                        team1  \
# 0        1    2017  Hyderabad   4/5/2017          Sunrisers Hyderabad
# 59      60    2008  Bangalore  4/18/2008        Kolkata Knight Riders
# 117    118    2009  Cape Town  4/18/2009               Mumbai Indians
# 174    175    2010     Mumbai  3/12/2010        Kolkata Knight Riders
# 234    235    2011    Chennai   4/8/2011          Chennai Super Kings
# 307    308    2012    Chennai   4/4/2012          Chennai Super Kings
# 381    382    2013    Kolkata   4/3/2013             Delhi Daredevils
# 457    458    2014  Abu Dhabi  4/16/2014        Kolkata Knight Riders
# 517    518    2015    Kolkata   4/8/2015               Mumbai Indians
# 576    577    2016     Mumbai   4/9/2016               Mumbai Indians
# 636   7894    2018     Mumbai   7/4/2018               Mumbai Indians
# 696  11137    2019    Chennai   23/03/19  Royal Challengers Bangalore
#
# ...

# %%
df1=pd.DataFrame({'Mobile name':['Redmi','Redmi','Samsung','oppo','oppo'],
                 'Rating':[4,4,3,2,1]})
df1
# Out:
#   Mobile name  Rating
# 0       Redmi       4
# 1       Redmi       4
# 2     Samsung       3
# 3        oppo       2
# 4        oppo       1

# %%
df1.drop_duplicates('Mobile name')
# Out:
#   Mobile name  Rating
# 0       Redmi       4
# 2     Samsung       3
# 3        oppo       2

# %%
df2['season']
# Out:
# 0      2017
# 59     2008
# 117    2009
# 174    2010
# 234    2011
# 307    2012
# 381    2013
# 457    2014
# 517    2015
# 576    2016
# 636    2018
# 696    2019
# Name: season, dtype: int64

# %%
df2['season'].shape
# Out:
# (12,)

# %%
data['toss_decision'].value_counts()
# Out:
# field    463
# bat      293
# Name: toss_decision, dtype: int64

# %% [markdown]
# Dataframe function drop_duplicates() :
#     Return DataFrame with duplicate rows removed.
#     Parameter :keep{‘first’, ‘last’, False}, default ‘first’
# Determines which duplicates (if any) to keep.
#
# ‘first’ : Drop duplicates except for the first occurrence.
#
# ‘last’ : Drop duplicates except for the last occurrence.
#
# False : Drop all duplicates.

# %% [markdown]
# Which Team had won by maximum wickets?

# %%
data['win_by_wickets']
# Out:
# 0       0
# 1       7
# 2      10
# 3       6
# 4       0
#        ..
# 751     9
# 752     6
# 753     2
# 754     6
# 755     0
# Name: win_by_wickets, Length: 756, dtype: int64

# %%
data['win_by_wickets'].value_counts()
# Out:
# 0     350
# 6      85
# 7      80
# 5      71
# 8      54
# 4      41
# 9      37
# 3      18
# 10     11
# 2       6
# 1       3
# Name: win_by_wickets, dtype: int64

# %%
data.iloc[data['win_by_wickets'].idxmax()]
# Out:
# id                                                      3
# season                                               2017
# city                                               Rajkot
# date                                             4/7/2017
# team1                                       Gujarat Lions
# team2                               Kolkata Knight Riders
# toss_winner                         Kolkata Knight Riders
# toss_decision                                       field
# result                                             normal
# dl_applied                                              0
# winner                              Kolkata Knight Riders
# win_by_runs                                             0
# win_by_wickets                                         10
# player_of_match                                   CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1                                       Nitin Menon
# ...

# %%
data.iloc[data['win_by_wickets'].idxmax()].winner
# Out:
# 'Kolkata Knight Riders'

# %% [markdown]
# Top player of the match Winners

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
data['player_of_match']
# Out:
# 0      Yuvraj Singh
# 1         SPD Smith
# 2           CA Lynn
# 3        GJ Maxwell
# 4         KM Jadhav
#            ...
# 751       HH Pandya
# 752        AS Yadav
# 753         RR Pant
# 754    F du Plessis
# 755       JJ Bumrah
# Name: player_of_match, Length: 756, dtype: object

# %%
data['player_of_match'].value_counts()
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
#                   ..
# PD Collingwood     1
# NV Ojha            1
# AC Voges           1
# J Theron           1
# S Hetmyer          1
# Name: player_of_match, Length: 226, dtype: int64

# %%
data['player_of_match'].value_counts()[:10]
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# MEK Hussey        12
# Name: player_of_match, dtype: int64

# %%
import seaborn as sns
top_player=data['player_of_match'].value_counts()[:10]
print(top_player.index)
sns.barplot(x=top_player,y=top_player.index)
# Out:
# Index(['CH Gayle', 'AB de Villiers', 'RG Sharma', 'MS Dhoni', 'DA Warner',
#        'YK Pathan', 'SR Watson', 'SK Raina', 'G Gambhir', 'MEK Hussey'],
#       dtype='object')
# <AxesSubplot:xlabel='player_of_match'>

# %% [markdown]
# Which are the most and least consistent teams across all seasons?

# %%
pd.crosstab(data['season'],data['winner'])
# Out:
# winner  Chennai Super Kings  Deccan Chargers  Delhi Capitals  \
# season
# 2008                      9                2               0
# 2009                      8                9               0
# 2010                      9                8               0
# 2011                     11                6               0
# 2012                     10                4               0
# 2013                     12                0               0
# 2014                     10                0               0
# 2015                     10                0               0
# 2016                      0                0               0
# 2017                      0                0               0
# 2018                     11                0               0
# 2019                     10                0              10
#
# winner  Delhi Daredevils  Gujarat Lions  Kings XI Punjab  \
# season
# 2008                   7              0               10
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,9))
data1=pd.crosstab(data['season'],data['winner'])
sns.heatmap(data1,annot=True)
# Out:
# <AxesSubplot:xlabel='winner', ylabel='season'>

# %% [markdown]
# Mumbai and Chennai are the two most successful teams so far. Which team leads in the head-to-head record?

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
data[['team1','team2']]
# Out:
#                            team1                        team2
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 751        Kolkata Knight Riders               Mumbai Indians
# 752          Chennai Super Kings               Mumbai Indians
# 753          Sunrisers Hyderabad               Delhi Capitals
# 754               Delhi Capitals          Chennai Super Kings
# 755               Mumbai Indians          Chennai Super Kings
#
# [756 rows x 2 columns]

# %%
((data.team1=='Mumbai Indians') & (data.team2=='Chennai Super Kings')) \
|((data.team1=='Chennai Super Kings') & (data.team2=='Mumbai Indians'))
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 751    False
# 752     True
# 753    False
# 754    False
# 755     True
# Length: 756, dtype: bool

# %%
mivscsk=data[((data.team1=='Mumbai Indians') & (data.team2=='Chennai Super Kings')) \
|((data.team1=='Chennai Super Kings') & (data.team2=='Mumbai Indians'))]

# %%
mivscsk
# Out:
#         id  season            city       date                team1  \
# 66      67    2008         Chennai  4/23/2008  Chennai Super Kings
# 95      96    2008          Mumbai  5/14/2008  Chennai Super Kings
# 117    118    2009       Cape Town  4/18/2009       Mumbai Indians
# 161    162    2009  Port Elizabeth  5/16/2009       Mumbai Indians
# 193    194    2010          Mumbai  3/25/2010  Chennai Super Kings
# 210    211    2010         Chennai   4/6/2010  Chennai Super Kings
# 233    234    2010          Mumbai  4/25/2010  Chennai Super Kings
# 256    257    2011          Mumbai  4/22/2011       Mumbai Indians
# 307    308    2012         Chennai   4/4/2012  Chennai Super Kings
# 354    355    2012          Mumbai   5/6/2012  Chennai Super Kings
# 378    379    2012       Bangalore  5/23/2012  Chennai Super Kings
# 385    386    2013         Chennai   4/6/2013       Mumbai Indians
# 429    430    2013          Mumbai   5/5/2013       Mumbai Indians
# ...

# %%
mivscsk.shape
# Out:
# (28, 18)

# %%
mivscsk['winner'].value_counts()
# Out:
# Mumbai Indians         17
# Chennai Super Kings    11
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(6,6))
plt.title("Mumbai Indians Vs Chennai Super Kings head-to head")
c1=mivscsk['winner'].value_counts()
sns.barplot(x=c1.index,y=c1)
# Out:
# <AxesSubplot:title={'center':'Mumbai Indians Vs Chennai Super Kings head-to head'}, ylabel='winner'>

# %%
data.iloc[data['win_by_runs'].idxmax()].winner
# Out:
# 'Mumbai Indians'

# %%
data.iloc[data['win_by_runs'].idxmax()]
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                       5/6/2017
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object
